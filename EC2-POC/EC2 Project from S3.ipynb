# %% [markdown]
# ####We are creating this project and we are reading data from S3 in AWS and reading data in Ec2 Machine and uploading in the s3 bucket again

# %% [markdown]
# ### In the below command we have created IAM role in the AWS and one S3 bucket and put some CSV, JSON,PARQUET Data in the s3 Bucket then we are going to read that data here using EC2 Machine

# %% [markdown]
# ####This is IAM Policy that we attached to the role

# %% [markdown]
# ![IAM Role Snapshot](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/Role%20Is%20Created.JPG)
# <br>

# %% [markdown]
# ### S3 Bucket Snapshot

# %% [markdown]
# ![S3 Bucket Snapshot](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/s3%20snpashot.JPG)
# <br>

# %% [markdown]
# ##This is Architecture Digram Of our POC

# %% [markdown]
# ![Arcitecture Diagram](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/Arch%20Diagram.JPG)
# <br>

# %% [markdown]
# ##Now we will create EC2 Machine

# %% [markdown]
# ![EC2 Diagram](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/EC2%20Machine%20Snapshot.JPG)
# <br>

# %% [markdown]
# ##Now we will attach the Role to EC2 Machine

# %% [markdown]
# #![EC2 IAM Diagram](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/Roleis%20attached.JPG)
# <br>

# %% [markdown]
# ## after uploading data in the s3 and attaching role to the machine we are able to read and upload data from machine to s3

# %% [markdown]
# #![EC2 IAM Connection](https://raw.githubusercontent.com/Vaishali-Vashist/EC2-POC/main/EC2%20POC/able%20to%20read%20and%20upt%20data.JPG)
# <br>

# %% [markdown]
# #Project POC is completed Now
